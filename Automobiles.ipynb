# %% [markdown]
# # Analyzing Used Car Listings on eBay

# %% [markdown]
# In this project, we'll work with a dataset of used cars from German eBay website.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
auc=pd.read_csv("auctioned.csv")

# %%
auc.head(2)
# Out:
#            dateCrawled                                        name  seller  \
# 0  2016-03-26 17:47:46            Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1  2016-04-04 13:38:56  BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
#
#   offerType   price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0   Angebot  $5,000  control         bus                2004    manuell
# 1   Angebot  $8,500  control   limousine                1997  automatik
#
#    powerPS   model   odometer  monthOfRegistration fuelType    brand  \
# 0      158  andere  150,000km                    3      lpg  peugeot
# 1      286     7er  150,000km                    6   benzin      bmw
#
#   notRepairedDamage          dateCreated  nrOfPictures  postalCode  \
# 0              nein  2016-03-26 00:00:00             0       79588
# 1              nein  2016-04-04 00:00:00             0       71034
#
#               lastSeen
# 0  2016-04-06 06:45:54
# 1  2016-04-06 14:45:08

# %%
auc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %%
auc = pd.read_csv("auctioned.csv", parse_dates=["dateCrawled","dateCreated","lastSeen"])
# auc["dateCrawled"]=pd.to_datetime(auc["dateCrawled"])
# auc["dateCreated"]=pd.to_datetime(auc["dateCreated"])
# auc["lastSeen"]=pd.to_datetime(auc["lastSeen"])

# %%
auc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  datetime64[ns]
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %%
auc.describe(include="all")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# ...

# %%
auc.isnull().sum()
# Out:
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            5095
# yearOfRegistration        0
# gearbox                2680
# powerPS                   0
# model                  2758
# odometer                  0
# monthOfRegistration       0
# fuelType               4482
# brand                     0
# notRepairedDamage      9829
# dateCreated               0
# nrOfPictures              0
# postalCode                0
# lastSeen                  0
# dtype: int64

# %%
auc[auc["vehicleType"].isnull()]
# Out:
#               dateCrawled                                               name  \
# 8     2016-03-22 16:51:34                                         Seat_Arosa
# 10    2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# 11    2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# 27    2016-03-27 18:45:01             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
# 46    2016-03-31 10:53:28                                       BMW_mit__Lpg
# ...                   ...                                                ...
# 49938 2016-03-28 18:45:06                     Mercedes_Benz_A_160_Avantgarde
# 49943 2016-03-16 20:46:08                                         Opel_astra
# 49984 2016-03-31 22:48:48  Student_sucht_ein__Anfaengerauto___ab_2000_BJ_...
# 49985 2016-04-02 16:38:23                          Verkaufe_meinen_vw_vento!
# 49991 2016-03-06 15:25:19                                         Kleinwagen
#
# ...

# %%
fill = auc.mode().to_dict(orient="record")[0]
fill
# Out:
# D:\anaconda\lib\site-packages\pandas\core\frame.py:1554: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   FutureWarning,
# {'dateCrawled': Timestamp('2016-03-05 16:57:05'),
#  'name': 'Ford_Fiesta',
#  'seller': 'privat',
#  'offerType': 'Angebot',
#  'price': '$0',
#  'abtest': 'test',
#  'vehicleType': 'limousine',
#  'yearOfRegistration': 2000.0,
#  'gearbox': 'manuell',
#  'powerPS': 0.0,
#  'model': 'golf',
#  'odometer': '150,000km',
#  'monthOfRegistration': 0.0,
#  'fuelType': 'benzin',
#  'brand': 'volkswagen',
#  'notRepairedDamage': 'nein',
#  'dateCreated': Timestamp('2016-04-03 00:00:00'),
#  'nrOfPictures': 0.0,
#  'postalCode': 10115.0,
#  'lastSeen': Timestamp('2016-04-07 06:17:27')}

# %%
auc.fillna(fill,inplace=True)

# %%
auc.isnull().sum()
# Out:
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# odometer               0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# nrOfPictures           0
# postalCode             0
# lastSeen               0
# dtype: int64

# %%
auc.head(3)
# Out:
#           dateCrawled                                        name  seller  \
# 0 2016-03-26 17:47:46            Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1 2016-04-04 13:38:56  BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
# 2 2016-03-26 18:57:24                  Volkswagen_Golf_1.6_United  privat
#
#   offerType   price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0   Angebot  $5,000  control         bus                2004    manuell
# 1   Angebot  $8,500  control   limousine                1997  automatik
# 2   Angebot  $8,990     test   limousine                2009    manuell
#
#    powerPS   model   odometer  monthOfRegistration fuelType       brand  \
# 0      158  andere  150,000km                    3      lpg     peugeot
# 1      286     7er  150,000km                    6   benzin         bmw
# 2      102    golf   70,000km                    7   benzin  volkswagen
#
#   notRepairedDamage dateCreated  nrOfPictures  postalCode            lastSeen
# ...

# %%
# strip for remove space by default starting and ending
auc["price"]=auc["price"].str.strip("$").str.replace(",","").astype(int)

# %%
auc["odometer"]=auc["odometer"].str.strip("km").str.replace(",","").astype(int)

# %%
# delete variables which are not useful. axis 1 mean column
auc.drop(["seller","offerType","nrOfPictures"],axis=1,inplace=True)

# %%
# check number of rows and columns
auc.shape
# Out:
# (50000, 17)

# %%
# data points rows*columns
50000*17
# Out:
# 850000

# %%
# unique values and their count
auc["yearOfRegistration"].value_counts().sort_index().head(15)
# Out:
# 1000    1
# 1001    1
# 1111    1
# 1500    1
# 1800    2
# 1910    9
# 1927    1
# 1929    1
# 1931    1
# 1934    2
# 1937    4
# 1938    1
# 1939    1
# 1941    2
# 1943    1
# Name: yearOfRegistration, dtype: int64

# %%
auc["yearOfRegistration"].value_counts().sort_index().tail(15)
# Out:
# 2016    1316
# 2017    1453
# 2018     492
# 2019       3
# 2800       1
# 4100       1
# 4500       1
# 4800       1
# 5000       4
# 5911       1
# 6200       1
# 8888       1
# 9000       2
# 9996       1
# 9999       4
# Name: yearOfRegistration, dtype: int64

# %%
# only take values between 1910-2016  we don't select 2017 and 2018 because we see on dateCrawled variable has latest 2016 so we know this data is till 2016
corrected_df=auc[auc["yearOfRegistration"].between(1910,2016)].copy()

# %%
corrected_df
# Out:
#               dateCrawled                                               name  \
# 0     2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3     2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_T�V_neu_ist_sehr_gepfleg...
# ...                   ...                                                ...
# 49995 2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996 2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___T�V_neu+...
# 49997 2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998 2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999 2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
corrected_df["yearOfRegistration"].min()
# Out:
# 1910

# %%
corrected_df["yearOfRegistration"].max()
# Out:
# 2016

# %%
corrected_df["price"].head(3)
# Out:
# 0    5000
# 1    8500
# 2    8990
# Name: price, dtype: int32

# %%
corrected_df["price"].value_counts().sort_index().tail(15)
# Out:
# 265000      1
# 295000      1
# 299000      1
# 345000      1
# 350000      1
# 999990      1
# 999999      2
# 1234566     1
# 1300000     1
# 3890000     1
# 10000000    1
# 11111111    2
# 12345678    1
# 27322222    1
# 99999999    1
# Name: price, dtype: int64

# %%
# only take values between 1-350000 because after 350000 there is a dummy values
cleaned_price=corrected_df[corrected_df["price"].between(1,350000)].copy()

# %%
cleaned_price
# Out:
#               dateCrawled                                               name  \
# 0     2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3     2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_T�V_neu_ist_sehr_gepfleg...
# ...                   ...                                                ...
# 49995 2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996 2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___T�V_neu+...
# 49997 2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998 2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999 2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
cleaned_price["price"].min()
# Out:
# 1

# %%
cleaned_price["price"].max()
# Out:
# 350000

# %%
cleaned_price.shape
# Out:
# (46681, 17)

# %%
# normalize brand to check which are the most selling brand
all_brand=cleaned_price["brand"].value_counts(normalize=True)*100
all_brand
# Out:
# volkswagen        21.126368
# bmw               11.004477
# opel              10.758124
# mercedes_benz      9.646323
# audi               8.656627
# ford               6.989996
# renault            4.714980
# peugeot            2.984083
# fiat               2.564212
# seat               1.827296
# skoda              1.640925
# nissan             1.527388
# mazda              1.518819
# smart              1.415994
# citroen            1.400998
# toyota             1.270324
# hyundai            1.002549
# sonstige_autos     0.981127
# volvo              0.914719
# mini               0.876159
# mitsubishi         0.822604
# honda              0.784045
# kia                0.706926
# alfa_romeo         0.664082
# porsche            0.612669
# suzuki             0.593389
# chevrolet          0.569825
# chrysler           0.351321
# dacia              0.263490
# daihatsu           0.250637
# jeep               0.227073
# subaru             0.214220
# land_rover         0.209936
# ...

# %%
# we only take the brands which are greater than 5
top_brand=all_brand[all_brand>5]
top_brand
# Out:
# volkswagen       21.126368
# bmw              11.004477
# opel             10.758124
# mercedes_benz     9.646323
# audi              8.656627
# ford              6.989996
# Name: brand, dtype: float64

# %%
top_brand.index
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
cleaned_price["brand"]
# Out:
# 0           peugeot
# 1               bmw
# 2        volkswagen
# 3             smart
# 4              ford
#             ...
# 49995          audi
# 49996          opel
# 49997          fiat
# 49998          audi
# 49999          opel
# Name: brand, Length: 46681, dtype: object

# %%
# only take the data where are these top brands 
popular_brand=cleaned_price[cleaned_price["brand"].isin(top_brand.index)]

# %%
popular_brand["brand"].unique()
# Out:
# array(['bmw', 'volkswagen', 'ford', 'mercedes_benz', 'audi', 'opel'],
#       dtype=object)

# %%
popular_brand["brand"].value_counts()
# Out:
# volkswagen       9862
# bmw              5137
# opel             5022
# mercedes_benz    4503
# audi             4041
# ford             3263
# Name: brand, dtype: int64

# %%
brand_mean_price=popular_brand.groupby("brand")["price"].mean().sort_values(ascending=False)

# %%
brand_mean_price
# Out:
# brand
# audi             9336.687454
# mercedes_benz    8628.450366
# bmw              8332.820518
# volkswagen       5402.410262
# ford             3749.469507
# opel             2975.241935
# Name: price, dtype: float64

# %%
brand_mean_milege=popular_brand.groupby("brand")["odometer"].mean().sort_values(ascending=False)

# %%
brand_mean_milege
# Out:
# brand
# bmw              132572.513140
# mercedes_benz    130788.363313
# opel             129310.035842
# audi             129157.386785
# volkswagen       128707.158791
# ford             124266.012872
# Name: odometer, dtype: float64

# %%
# convert series into dataframe
price_mil=pd.DataFrame(brand_mean_price)

# %%
price_mil
# Out:
#                      price
# brand
# audi           9336.687454
# mercedes_benz  8628.450366
# bmw            8332.820518
# volkswagen     5402.410262
# ford           3749.469507
# opel           2975.241935

# %%
# change column name
price_mil.columns=["mean_price"]

# %%
price_mil
# Out:
#                 mean_price
# brand
# audi           9336.687454
# mercedes_benz  8628.450366
# bmw            8332.820518
# volkswagen     5402.410262
# ford           3749.469507
# opel           2975.241935

# %%
# removing index name
price_mil.index.name=None

# %%
price_mil
# Out:
#                 mean_price
# audi           9336.687454
# mercedes_benz  8628.450366
# bmw            8332.820518
# volkswagen     5402.410262
# ford           3749.469507
# opel           2975.241935

# %%
# add column mean_milege on price_mil data frame
price_mil["mean_milege"]=brand_mean_milege

# %%
price_mil
# Out:
#                 mean_price    mean_milege
# audi           9336.687454  129157.386785
# mercedes_benz  8628.450366  130788.363313
# bmw            8332.820518  132572.513140
# volkswagen     5402.410262  128707.158791
# ford           3749.469507  124266.012872
# opel           2975.241935  129310.035842

# %%
price_mil.plot.bar()
plt.show()

# %%
# normalize the data
normalize=price_mil.copy()

# %%
cols = price_mil.columns
cols
# Out:
# Index(['mean_price', 'mean_milege'], dtype='object')

# %%
for i in cols:
    normalize[i] = normalize[i]/normalize[i].sum()

# %%
normalize
# Out:
#                mean_price  mean_milege
# audi             0.242984     0.166697
# mercedes_benz    0.224553     0.168802
# bmw              0.216859     0.171105
# volkswagen       0.140596     0.166116
# ford             0.097579     0.160384
# opel             0.077430     0.166894

# %%
normalize.plot.bar(title = "brands price and mileage comparision", 
                   color = ["blue", "red"], rot = 75)
plt.xlabel("Brands")
plt.ylabel("price & milege")
plt.show()

# %%
popular_brand.head(3)
# Out:
#           dateCrawled                                               name  \
# 1 2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2 2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4 2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_T�V_neu_ist_sehr_gepfleg...
#
#    price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 1   8500  control   limousine                1997  automatik      286    7er
# 2   8990     test   limousine                2009    manuell      102   golf
# 4   1350     test       kombi                2003    manuell        0  focus
#
#    odometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 1    150000                    6   benzin         bmw              nein
# 2     70000                    7   benzin  volkswagen              nein
# 4    150000                    7   benzin        ford              nein
#
#   dateCreated  postalCode            lastSeen
# ...

# %%
brand_model=popular_brand.groupby("brand")["model"].value_counts()

# %%
brand_model
# Out:
# brand       model
# audi        a4         1231
#             a3          825
#             a6          797
#             andere      216
#             80          198
#                        ...
# volkswagen  up           51
#             jetta        38
#             phaeton      31
#             cc           18
#             amarok        6
# Name: model, Length: 101, dtype: int64

# %%
brand_model["audi"].index[0]
# Out:
# 'a4'

# %%
top_brand.index
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
c_b=top_brand.index

# %%
for i in c_b:
    print(i)
# Out:
# volkswagen
# bmw
# opel
# mercedes_benz
# audi
# ford

# %%
b_top_m={}
for i in c_b:
    model=brand_model[i].index[0]
    b_top_m[i]=model

# %%
print("top cars brand and their top model")
b_top_m
# Out:
# top cars brand and their top model
# {'volkswagen': 'golf',
#  'bmw': '3er',
#  'opel': 'corsa',
#  'mercedes_benz': 'c_klasse',
#  'audi': 'a4',
#  'ford': 'focus'}
